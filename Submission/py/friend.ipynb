# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC  
from sklearn.model_selection import train_test_split
from sklearn import cross_validation,metrics
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, roc_auc_score, classification_report, roc_curve, auc
# Out:
# E:\Tools\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
friend=pd.read_csv("C:/Users/yichen/Desktop/friend.csv")
user_6000friends_reviewstardate_businesslocstar=pd.read_csv("C:/Users/yichen/Desktop/user_6000friends_reviewstardate_businesslocstar.csv",encoding='gb2312')
friend_business=user_6000friends_reviewstardate_businesslocstar[['friend_id','business_id']]

# %%
friendA=pd.merge(friend,friend_business,left_on='A',right_on='friend_id',how='inner')
friendA.rename(columns={'business_id':'business_idA'},inplace=True)
#del friendA['friend_id']
#friendAB=pd.merge(friendA,friend_business,left_on='B',right_on='friend_id',how='inner')
#friendAB.rename(columns={'business_id':'business_idB'},inplace=True)
#del friendAB['friend_id']
#common_business=friendAB[friendAB['business_idA']==friendAB['business_idB']]
friendA
# Out:
#                             A                       B  same restaurant count  \
# 0      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 1      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 2      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 3      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 4      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 5      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 6      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 7      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 8      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 9      PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# 10     PcvbBOCOcs6_suRDH7TSTg  e6iCOIhtupBCiw-VwBvJ4A                    NaN
# ...

# %%
#common_businessAB=common_business.groupby(['A','B'],as_index=False).count()

# %%
#friend_samecount=pd.merge(friend,common_businessAB,on=['A','B'],how='left')
#del friend_samecount['same restaurant count_x']
#friend_samecount.rename(columns={'same restaurant count_y':'same restaurant count'},inplace=True)

#friend_samecount.loc[friend_samecount['same restaurant count'].isnull(), 'same restaurant count'] = 0
#friend_samecount['same restaurant count'] = friend_samecount['same restaurant count'].astype(int)
friend_samecount.to_csv('friend.csv')

# %%
#common_businessAB=common_businessAB[['A','B','business_idA']]
#common_businessAB.rename(columns={'business_idA':'same restaurant count'},inplace=True)
#common_businessAB

# %%
''''
t=friend[80:]
friendB=pd.merge(t,friend_business,left_on='B',right_on='friend_id',how='inner')
del friendB['friend_id']
friendB.rename(columns={'business_id':'business_idB'},inplace=True)
review_notext=pd.read_csv("E:/DATA/DATA in CU Boulder/CSCI 5622/review_info_notext.csv")
popuser=review_notext[review_notext['user_id']=='3zxy3LVBV3ttxoYbY4rQ8A']
popuser=popuser[['business_id','user_id']]
friendABpopuser=pd.merge(popuser,friendB,left_on='user_id',right_on='A',how='inner')
del friendABpopuser['user_id']
common_businessPopuser=friendABpopuser[friendABpopuser['business_id']==friendABpopuser['business_idB']]
common_businessPopuser_final=common_businessPopuser.groupby((['A','B']),as_index=False).count()
del common_businessPopuser_final['business_id']
del common_businessPopuser_final['same restaurant count']
common_businessPopuser_final.rename(columns={'business_idB':'same restaurant count'},inplace=True)
#common_businessPopuser_final
friend_samecount=pd.merge(t,common_businessPopuser_final,on=['A','B'],how='left')
del friend_samecount['same restaurant count_x']
friend_samecount.loc[friend_samecount['same restaurant count_y'].isnull(), 'same restaurant count_y'] = 0
friend_samecount['same restaurant count_y'] = friend_samecount['same restaurant count_y'].astype(int)
#friend_samecount.to_csv('popuserfriend.csv')]
del review_notext
'''
user=pd.read_csv("E:/DATA/DATA in CU Boulder/CSCI 5622/review_info_notext.csv")
